# %%
# %pylab inline
import skimage
import numpy as np
from pathlib import Path
import skimage.io
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Image R2D2-20x-1

# %%
im = skimage.io.imread(r"g:/Můj disk/data/biology/orig/roots/examples/R2D2-20x-1.tif")
im.shape
# Out:
# (46, 2, 1200, 542)

# %% [markdown]
# ## Channel Fusion

# %%
i = 20
plt.figure(figsize=[15,10])
plt.subplot(131)
plt.imshow(im[i,0,:,:])
plt.colorbar()
plt.subplot(132)
plt.imshow(im[i,1,:,:])
plt.colorbar()

im0 = im[i,0,:,:]
im1 = im[i,1,:,:]
# print(im0.shape)
fusion = np.zeros([im0.shape[0], im0.shape[1], 3])

fusion[:,:,0] = im0 / np.max(im0)
fusion[:,:,1] = im1 / np.max(im1)

plt.subplot(133)
plt.imshow(fusion)

# %% [markdown]
# ## Time difference image

# %%
plt.figure(figsize=[15,10])
plt.imshow(im[i,0,:,:].astype(float)-im[i+1,0,:,:].astype(float))
plt.colorbar()

# %% [markdown]
# # Image DIIVenus-20x-1.tif

# %%
im = skimage.io.imread(r"g:/Můj disk/data/biology/orig/roots/examples/DIIVenus-20x-1.tif")

# %%
i = 20
plt.figure(figsize=[15,10])
plt.subplot(131)
plt.imshow(im[i,0,:,:])
plt.colorbar()
plt.subplot(132)
plt.imshow(im[i,1,:,:])
plt.colorbar()

im0 = im[i,0,:,:]
im1 = im[i,1,:,:]
# print(im0.shape)
fusion = np.zeros([im0.shape[0], im0.shape[1], 3])

fusion[:,:,0] = im0 / np.max(im0)
fusion[:,:,1] = im1 / np.max(im1)

plt.subplot(133)
plt.imshow(fusion)

# %%
plt.figure(figsize=[15,10])
plt.imshow(im[i,0,:,:].astype(float)-im[i+1,0,:,:].astype(float))
plt.colorbar()

# %% [markdown]
# # DIIVenus-20x-2

# %%
im = skimage.io.imread(r"g:/Můj disk/data/biology/orig/roots/examples/DIIVenus-20x-2.tif")
# im.shape

# %%
i = 20
plt.figure(figsize=[15,10])
plt.subplot(131)
plt.imshow(im[i,0,:,:])
plt.colorbar()
plt.subplot(132)
plt.imshow(im[i,1,:,:])
plt.colorbar()

im0 = im[i,0,:,:]
im1 = im[i,1,:,:]
# print(im0.shape)
fusion = np.zeros([im0.shape[0], im0.shape[1], 3])

fusion[:,:,0] = im0 / np.max(im0)
fusion[:,:,1] = im1 / np.max(im1)

plt.subplot(133)
plt.imshow(fusion)

# %% [markdown]
# # Image R2D2-40-1

# %%
im = skimage.io.imread(r"g:/Můj disk/data/biology/orig/roots/examples/R2D2-40x-1.tif")
im.shape
# Out:
# (74, 2, 1200, 976)

# %%
i = 20
plt.figure(figsize=[15,10])
plt.subplot(131)
plt.imshow(im[i,0,:,:])
plt.colorbar()
plt.subplot(132)
plt.imshow(im[i,1,:,:])
plt.colorbar()

im0 = im[i,0,:,:]
im1 = im[i,1,:,:]
# print(im0.shape)
fusion = np.zeros([im0.shape[0], im0.shape[1], 3])

fusion[:,:,0] = im0 / np.max(im0)
fusion[:,:,1] = im1 / np.max(im1)

plt.subplot(133)
plt.imshow(fusion)

# %%
plt.figure(figsize=[15,10])
plt.imshow(im[i,0,:,:].astype(float)-im[i+1,0,:,:].astype(float))
plt.colorbar()

# %% [markdown]
# # TIFF metadata

# %%
from PIL import Image
from PIL.TiffTags import TAGS

fn = r"g:/Můj disk/data/biology/orig/roots/examples/R2D2-40x-1.tif"
with Image.open(fn) as img:
    meta_dict = {TAGS[key] : img.tag[key] for key in img.tag}
print(meta_dict)
# Out:
# {'ImageWidth': (976,), 'ImageLength': (1200,), 'BitsPerSample': (16,), 'PhotometricInterpretation': (1,), 'ResolutionUnit': (1,), 'ImageJMetaData': b'IJIJrang\x00\x00\x00\x01luts\x00\x00\x00\x02@S\x80\x00\x00\x00\x00\x00@\x86x\x00\x00\x00\x00\x00@S\x80\x00\x00\x00\x00\x00@\
# ...

# %%
key_value = [couplestring.split("=") for couplestring in meta_dict["ImageDescription"][0].split("\n") ]
# print(key_value)
image_description = {kv[0]: kv[1] for kv in key_value if len(kv) > 1}
print(image_description)
# Out:
# {'ImageJ': '1.52p', 'images': '148', 'channels': '2', 'slices': '74', 'hyperstack': 'true', 'mode': 'composite', 'unit': 'micron', 'spacing': '0.6', 'loop': 'false', 'min': '78.0', 'max': '1080.0'}

# %% [markdown]
# ## Other file

# %%
from PIL import Image
from PIL.TiffTags import TAGS
fn = r"g:/Můj disk/data/biology/orig/roots/examples/R2D2-20x-1.tif"
# fn = r"g:/Můj disk/data/biology/orig/roots/examples/DIIVenus-20x-2.tif"
# fn = r"g:/Můj disk/data/biology/orig/roots/examples/R2D2-40x-1.tif"
with Image.open(fn) as img:
    meta_dict = {TAGS[key] : img.tag[key] for key in img.tag}
print(meta_dict)
# Out:
# {'ImageWidth': (542,), 'ImageLength': (1200,), 'BitsPerSample': (16,), 'PhotometricInterpretation': (1,), 'ResolutionUnit': (1,), 'ImageJMetaData': b'IJIJrang\x00\x00\x00\x01luts\x00\x00\x00\x02@S\x80\x00\x00\x00\x00\x00@\x86x\x00\x00\x00\x00\x00@S\x80\x00\x00\x00\x00\x00@\
# ...

# %%
key_value = [couplestring.split("=") for couplestring in meta_dict["ImageDescription"][0].split("\n") ]
# print(key_value)
image_description = {kv[0]: kv[1] for kv in key_value if len(kv) > 1}
print(image_description)
# Out:
# {'ImageJ': '1.52p', 'images': '92', 'channels': '2', 'slices': '46', 'hyperstack': 'true', 'mode': 'composite', 'unit': 'micron', 'loop': 'false', 'min': '78.0', 'max': '719.0'}

# %% [markdown]
# # Rearrange data

# %%
plt.imshow(im[(0,0, slice(None), slice(None))])

# %%
im[(slice(None),1, slice(None), slice(None))].ndim
# Out:
# 3

# %%
list(np.asarray(im.shape)/2)
# Out:
# [37.0, 1.0, 600.0, 488.0]

# %%
timestamp = datetime.datetime.now().strftime("SA_%Y%m%d_%H%M%S")
timestamp
# Out:
# 'SA_20200330_114107'

# %%
str(datetime.datetime.now())
# Out:
# '2020-03-30 11:41:28.667266'

# %%
uu = "asdfa:asdfsf:oiuowei".split(":")
last = uu.pop(-1)
":".join(uu)
# Out:
# 'asdfa:asdfsf'
